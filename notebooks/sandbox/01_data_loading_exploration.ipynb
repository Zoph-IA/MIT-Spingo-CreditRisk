# %%
# ---
# 01_data_loading_exploration.ipynb
# Sandbox: Data Loading & Initial Exploration
# ---

# %%
# %pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /Users/enriquegomeztagle/anaconda3/envs/stats/lib/python3.11/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
DATA_PATH = '../../data/bronze/HubSpot CRM All Contacts Feb 27 2025.xls'

# %%
view_head = False
try:
    df = pd.read_excel(DATA_PATH)
    n_cols = df.shape
    n_rows = df.shape[0]
    print("Dataset loaded successfully with {} rows and {} columns.".format(n_rows, n_cols[1]))
    view_head = True
except Exception as e:
    print(f"Error loading dataset: {e}")
# Out:
# Dataset loaded successfully with 10422 rows and 249 columns.

# %%
if view_head:
    display(df.head())
# Out:
#       Record ID First Name         Last Name  ¿Cuál es el año de tu auto?  \
# 0  102722040939     Hector             Ponce                          NaN
# 1  102729179904     Hector             Ponce                          NaN
# 2  102688963980     Hector             Ponce                          NaN
# 3  102646482708        NaN               NaN                          NaN
# 4  102630634618      Erick  Hernandez Castro                          NaN
#
#    ¿Cuál es la marca y modelo de tu auto? ¿Cuál es modelo y año de tu auto?  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#   ¿Cuál es tu nombre completo? ¿Cuentas con la factura original del auto?  \
# 0                          NaN                                        NaN
# 1                          NaN                                        NaN
# 2                          NaN                                        NaN
# 3                          NaN                                        NaN
# 4                          NaN                                        NaN
#
#    ¿Cuentas con la factura original del auto?v2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ¿Tu auto es del año 2010 o más actual?  ...  \
# 0                                     NaN  ...
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
#
#    Recent Sales Email Opened Date Recent Sales Email Replied Date  \
# 0                             NaT                             NaT
# 1                             NaT                             NaT
# 2                             NaT                             NaT
# 3                             NaT                             NaT
# 4                             NaT                             NaT
#
#   Rechazo cliente  Rechazo spingo  Record source  \
# 0             NaN              NaN   Integration
# 1             NaN              NaN   Integration
# 2             NaN              NaN   Integration
# 3             NaN              NaN         Forms
# 4             NaN              NaN   Integration
#
#                               Record source detail 1  Record source detail 2  \
# 0                                     SpinGo-Chatbot                     NaN
# 1                                     SpinGo-Chatbot                     NaN
# 2                                     SpinGo-Chatbot                     NaN
# 3  Subscribe to Blog de SpinGo - Tips sobre empeñ...                     NaN
# 4                                      API Simulator                     NaN
#
#    Record source detail 3 Referencias totales Referente
# 0                     NaN                 NaN       NaN
# 1                     NaN                 NaN       NaN
# 2                     NaN                 NaN       NaN
# 3                     NaN                 NaN       NaN
# 4                     NaN                 NaN       NaN
#
# [5 rows x 249 columns]

# %%
df.columns
# Out:
# Index(['Record ID', 'First Name', 'Last Name', '¿Cuál es el año de tu auto?',
#        '¿Cuál es la marca y modelo de tu auto?',
#        '¿Cuál es modelo y año de tu auto?', '¿Cuál es tu nombre completo?',
#        '¿Cuentas con la factura original del auto?',
#        '¿Cuentas con la factura original del auto?v2',
#        '¿Tu auto es del año 2010 o más actual?',
#        ...
#        'Recent Sales Email Opened Date', 'Recent Sales Email Replied Date',
#        'Rechazo cliente', 'Rechazo spingo ', 'Record source',
#        'Record source detail 1', 'Record source detail 2',
#        'Record source detail 3', 'Referencias totales', 'Referente'],
#       dtype='object', length=249)
